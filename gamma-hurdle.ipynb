# %% [markdown]
# ## Gamma Hurdle Models

# %% [markdown]
# This sample script demonstrates how gamma hurdle model can be fit to analyse zero-inflated data.

# %%
Sys.time()
# Out:
# [1] "2019-03-15 15:18:08 GMT"

# %% [markdown]
# ### Data description:
# Cape Clear Data 1971-2017
# Explain here how data was collected and which parts of the data are reliable.
#
# ### Research questions:
#
# 1. Has the number of sunfish sighted increased over time?
# 2. Can observed change be related to changes in wind speed or direction, food availability and sea surface temperature?

# %%
set.seed(4322)

# %%
# load packages
# library(R.utils)
library(ggplot2)
# library(GGally)
# library(lmtest)
# library(plyr)
# library(tidyverse)
library(lme4)
library(effects)
library(optimx)
# Out:
# Loading required package: carData
# lattice theme set by effectsTheme()
# See ?effectsTheme for details.

# %%
# require(devtools)
# install_version("effects", version = "4.0-0")

# %%
dat <- read.csv('sunfish.csv')
plot(dat$year, dat$nsunfishm, pch=20, col="blue", xlab="year",ylab="number of sunfish per minute", xlim=c(1970, 2020))
# Out:
# plot without title
